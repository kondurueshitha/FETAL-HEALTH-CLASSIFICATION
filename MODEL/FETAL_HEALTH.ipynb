# %% [markdown]
# ## FETAL HEALTH CLASSIFICATION

# %% [markdown]
# ## Importing the libraries required

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ## Reading the data

# %%
df=pd.read_csv('fetal_health.csv')
df.head()
# Out:
#    baseline value  accelerations  ...  histogram_tendency  fetal_health
# 0           120.0          0.000  ...                 1.0           2.0
# 1           132.0          0.006  ...                 0.0           1.0
# 2           133.0          0.003  ...                 0.0           1.0
# 3           134.0          0.003  ...                 1.0           1.0
# 4           132.0          0.007  ...                 1.0           1.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %% [markdown]
# # Shape of the data

# %%
df.shape
# Out:
# (2126, 22)

# %% [markdown]
# ##Describe() is used to view some basic statistical details like mean,std etc.

# %%
df.describe().transpose()
# Out:
#                                                      count  ...      max
# baseline value                                      2126.0  ...  160.000
# accelerations                                       2126.0  ...    0.019
# fetal_movement                                      2126.0  ...    0.481
# uterine_contractions                                2126.0  ...    0.015
# light_decelerations                                 2126.0  ...    0.015
# severe_decelerations                                2126.0  ...    0.001
# prolongued_decelerations                            2126.0  ...    0.005
# abnormal_short_term_variability                     2126.0  ...   87.000
# mean_value_of_short_term_variability                2126.0  ...    7.000
# percentage_of_time_with_abnormal_long_term_vari...  2126.0  ...   91.000
# mean_value_of_long_term_variability                 2126.0  ...   50.700
# histogram_width                                     2126.0  ...  180.000
# ...

# %% [markdown]
# ## Check if any null values is present in the given data

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %% [markdown]
# ## Duplicate values in the given data

# %%
df.duplicated().sum()
# Out:
# 13

# %% [markdown]
# ## Drop the duplicates found in the data

# %%
df.drop_duplicates()
# Out:
#       baseline value  accelerations  ...  histogram_tendency  fetal_health
# 0              120.0          0.000  ...                 1.0           2.0
# 1              132.0          0.006  ...                 0.0           1.0
# 2              133.0          0.003  ...                 0.0           1.0
# 3              134.0          0.003  ...                 1.0           1.0
# 4              132.0          0.007  ...                 1.0           1.0
# ...              ...            ...  ...                 ...           ...
# 2121           140.0          0.000  ...                 0.0           2.0
# 2122           140.0          0.001  ...                 1.0           2.0
# 2123           140.0          0.001  ...                 1.0           2.0
# 2124           140.0          0.001  ...                 1.0           2.0
# 2125           142.0          0.002  ...                 0.0           1.0
#
# [2113 rows x 22 columns]

# %% [markdown]
# ## Importing matplot library to plot the data

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Check whether the data is balanced or imbalanced

# %%
sns.countplot(data = df,x = "fetal_health")
plt.title("fetal health",fontsize = 20)
# Out:
# Text(0.5, 1.0, 'fetal health')

# %% [markdown]
# ## Coorelation of the data

# %%
corr = df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True, center=0)

# %%
plot=['baseline value', 'accelerations', 'fetal_movement',
       'uterine_contractions', 'light_decelerations', 'severe_decelerations',
       'prolongued_decelerations', 'abnormal_short_term_variability',
       'mean_value_of_short_term_variability',
       'percentage_of_time_with_abnormal_long_term_variability',
       'mean_value_of_long_term_variability']

# %%
for i in plot:
    sns.boxplot(x=df["fetal_health"], y=df[i])
    plt.show()

# %% [markdown]
# ## seperating dependent and independent variables

# %%
x = df.iloc[:,0: -1]
y = df.iloc[:,-1]

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data =x)
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import  confusion_matrix, classification_report,accuracy_score

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
plt.figure(figsize=(20,10))
sns.boxplot(data =x)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Splitting the data

# %%
X_train, X_test, y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Model building

# %%
pipeline_lr=Pipeline([('lr_classifier',LogisticRegression(random_state=42))])
pipeline_dT=Pipeline([ ('dT_classifier',DecisionTreeClassifier(random_state=42))])
pipeline_Rf=Pipeline([('Rf_classifier',RandomForestClassifier())])
pipeline_svc=Pipeline([('svc',SVC())])
pipelines = [pipeline_lr, pipeline_dT, pipeline_Rf, pipeline_svc]
pipe_dict = {0: 'Logistic Regression', 1: 'Decision Tree', 2: 'RandomForest', 3: "SVC"}

# %% [markdown]
# ## Using pipelines to get faster results

# %%
for pipes in pipelines:
  pipes.fit(X_train,y_train)

# %%
cv_accuracy = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train,y_train, cv=10 )
    cv_accuracy.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Logistic Regression: 0.897170
# Decision Tree: 0.916683
# RandomForest: 0.939529
# SVC: 0.906594

# %% [markdown]
# ## From the above results Random forest gave me more accuracy,so evaluating the random forest

# %%
Rf =RandomForestClassifier()
Rf.fit( X_train,y_train)
k = Rf.predict(X_test)
accuracy=accuracy_score(y_test,k)
accuracy
# Out:
# 0.9404388714733543

# %%
param_grid={'n_estimators': [100,150, 200,500,700,900],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,6,8,12,14,16],
    'criterion' :['gini', 'entropy'],
    'n_jobs':[-1,1,None]
}

# %%
Grid_cv_Rf=GridSearchCV(estimator=RandomForestClassifier(),param_grid=param_grid,cv=5)
Grid_cv_Rf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
Grid_cv_Rf.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 14,
#  'max_features': 'auto',
#  'n_estimators': 200,
#  'n_jobs': -1}

# %%
RF=RandomForestClassifier(**Grid_cv_Rf.best_params_)
RF.fit(X_train,y_train)
predictions=RF.predict(X_test)
Accuracy=accuracy_score(y_test,predictions)*100
print('ACCURACY SCORE:',Accuracy)
# Out:
# ACCURACY SCORE: 94.35736677115987

# %%
clf = GradientBoostingClassifier(n_estimators=200)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9592476489028213

# %%
cf=confusion_matrix(y_test,y_pred)
sns.heatmap(cf/np.sum(cf),annot=True)
